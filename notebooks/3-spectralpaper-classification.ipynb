# %% [markdown]
# <div style="background: linear-gradient(135deg, #141E30, #243B55);
#             padding: 24px;
#             border-radius: 14px;
#             color: #f5f5f5;
#             font-family: 'Segoe UI', sans-serif;
#             box-shadow: 2px 2px 14px rgba(0,0,0,0.35);">
#
#   <h2 style="margin-top:0; text-align:center; font-size:24px;">🤖 Model Training & Evaluation</h2>
#
#   <p style="font-size:15px; line-height:1.6;">
#     In this section, we load the <b>extracted spectral features</b>, split them into
#     <b>training and testing sets</b>, and evaluate multiple machine learning classifiers.
#     Each model produces performance metrics and a <b>colored confusion matrix</b>.
#   </p>
#
#   <hr style="border: 1px solid rgba(255,255,255,0.25);">
#
#   <h3 style="margin-bottom:6px;">📌 Models Trained</h3>
#   <ul style="font-size:14px; line-height:1.6;">
#     <li>📈 Linear Discriminant (LD)</li>
#     <li>📊 Kernel Naïve Bayes (KNB) & Gaussian NB (GNB)</li>
#     <li>🌳 Fine Tree (FT) & Bagged Trees (BT)</li>
#     <li>🔎 Fine KNN (FKNN) & Subspace KNN (SKNN)</li>
#     <li>⚙️ Support Vector Machines (SVM) with:
#       <ul>
#         <li>Linear, Quadratic, Cubic</li>
#         <li>Fine / Medium / Coarse Gaussian kernels</li>
#       </ul>
#     </li>
#   </ul>
#
#   <h3 style="margin-bottom:6px;">📌 Evaluation Metrics</h3>
#   <ul style="font-size:14px; line-height:1.6;">
#     <li>✔️ Accuracy, Precision, Recall, F1-score</li>
#     <li>✔️ Type I Error (False Positive Rate)</li>
#     <li>✔️ Type II Error (False Negative Rate)</li>
#     <li>✔️ Confusion Matrix (visualized with different colormaps)</li>
#   </ul>
#
#   <p style="font-size:14px; line-height:1.6;">
#     ✅ Running this code will train and test all models, print their performance reports,
#     and display confusion matrices with unique color schemes — making it easier to compare
#     how well each classifier separates <span style="color:#FFD700;">Normal</span>,
#     <span style="color:#FF6347;">Asthama</span>, and
#     <span style="color:#ADFF2F;">Pneumonia</span> classes.
#   </p>
# </div>

# %% [markdown]
# <style>
# :root{--bg:#0b1020;--ink:#ecf1ff;--muted:#a9b4d0;--card1:#2d6cdf;--card2:#8e5cf6;--card3:#00b894;--card4:#ff7675;--card5:#f39c12;--card6:#e84393;}
# /* container */
# .mm {font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Arial; color:var(--ink); background:linear-gradient(180deg,#0b1020 0%,#111936 100%); border:1px solid #1f2a44; border-radius:16px; padding:20px; box-shadow: 0 12px 30px rgba(0,0,0,.3);}
# .mm h1{margin:0 0 10px;font-size:22px;letter-spacing:.3px}
# .mm p{margin:.25rem 0;color:var(--muted);font-size:14px}
# .grid{display:grid;grid-template-columns:repeat(auto-fit,minmax(240px,1fr)); gap:12px;margin-top:12px}
# .card{border-radius:14px; padding:14px; border:1px solid rgba(255,255,255,.08); background:rgba(255,255,255,.04); backdrop-filter: blur(6px)}
# .card h3{margin:0 0 8px;font-size:16px}
# .badge{display:inline-block;padding:4px 8px;border-radius:999px;font-weight:600;font-size:12px;letter-spacing:.3px; background:rgba(255,255,255,.12)}
# .tag{display:inline-block;margin:2px 4px 0 0; padding:3px 8px;border-radius:999px;font-size:12px;background:rgba(255,255,255,.1)}
# .eq{background:rgba(0,0,0,.35); padding:8px 10px;border-radius:10px; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size:13px; overflow:auto}
# .hint{font-size:12px;color:#d6dcff;opacity:.85;margin-top:6px}
# .gradient1{background:linear-gradient(135deg,var(--card1),#4aa3ff)}
# .gradient2{background:linear-gradient(135deg,var(--card2),#b884ff)}
# .gradient3{background:linear-gradient(135deg,var(--card3),#20e3ad)}
# .gradient4{background:linear-gradient(135deg,var(--card4),#ffa3a1)}
# .gradient5{background:linear-gradient(135deg,var(--card5),#ffd56e)}
# .gradient6{background:linear-gradient(135deg,var(--card6),#ff9ed1)}
# .header{display:flex;align-items:center;gap:8px;margin-bottom:8px}
# .dot{width:8px;height:8px;border-radius:50%}
# .small{font-size:12px;color:var(--muted)}
# </style>
#
# <div class="mm">
#
# <h1>🎨 Your Models — Ultra‑Concise, Visual & Math‑savvy</h1>
# <p class="small">Keys → algorithms, what they do, and the one formula/idea to remember. Use as a slide-ready explainer.</p>
#
# <div class="grid">
#
#   <div class="card">
#     <div class="header"><span class="dot" style="background:var(--card1)"></span><h3>LDA <span class="badge gradient1">LD</span></h3></div>
#     <p>Linear boundaries from shared-covariance Gaussians.</p>
#     <div class="eq">\( \delta_c(x)=x^\top\Sigma^{-1}\mu_c-\tfrac12\mu_c^\top\Sigma^{-1}\mu_c+\ln\pi_c \)</div>
#   </div>
#
#   <div class="card">
#     <div class="header"><span class="dot" style="background:var(--card2)"></span><h3>Gaussian Naive Bayes <span class="badge gradient2">KNB, GNB</span></h3></div>
#     <p>Independence across features; fast generative classifier.</p>
#     <div class="eq">\( P(y=c\mid x)\propto \pi_c \prod_j \mathcal{N}(x_j;\mu_{cj},\sigma_{cj}^2) \)</div>
#   </div>
#
#   <div class="card">
#     <div class="header"><span class="dot" style="background:var(--card3)"></span><h3>Decision Tree <span class="badge gradient3">FT</span></h3></div>
#     <p>Greedy splits to reduce impurity.</p>
#     <div class="eq">\( \Delta = G_{\text{parent}}-\tfrac{w_L}{w}G_L-\tfrac{w_R}{w}G_R \quad (G=1-\sum_c p_c^2) \)</div>
#   </div>
#
#   <div class="card">
#     <div class="header"><span class="dot" style="background:var(--card4)"></span><h3>k‑NN <span class="badge gradient4">FKNN, SKNN</span></h3></div>
#     <p>Vote of neighbors (distance‑weighted in SKNN).</p>
#     <div class="eq">\( w_i=\frac{1}{\lVert x-x_{(i)}\rVert+\varepsilon},\quad \hat y=\arg\max_c \sum_{i\in\mathcal N_k} w_i\,\mathbf1[y_i=c] \)</div>
#     <p class="hint">Scale features; choose k by CV.</p>
#   </div>
#
#   <div class="card">
#     <div class="header"><span class="dot" style="background:var(--card5)"></span><h3>Bagging (Trees) <span class="badge gradient5">BT</span></h3></div>
#     <p>Bootstrap many trees; average votes → lower variance.</p>
#     <div class="eq">\( \hat y=\arg\max_c \sum_{b=1}^B \mathbf1[h_b(x)=c] \)</div>
#   </div>
#
#   <div class="card">
#     <div class="header"><span class="dot" style="background:var(--card6)"></span><h3>SVM Family <span class="badge gradient6">SVM_*</span></h3></div>
#     <p>Max‑margin classifier; kernels add nonlinearity.</p>
#     <div class="eq">Linear: \( f(x)=w^\top x+b \) (soft‑margin \(C\)).</div>
#     <div class="eq">Poly: \( K(x,x')=(\gamma x^\top x' + r)^d \) — <span class="tag">d=2 (quadratic)</span><span class="tag">d=3 (cubic)</span></div>
#     <div class="eq">RBF: \( K(x,x')=\exp(-\gamma\lVert x-x'\rVert^2) \) — <span class="tag">γ=5 fine</span><span class="tag">0.5 medium</span><span class="tag">0.05 coarse</span></div>
#     <p class="hint">Tune \(C,\gamma\); probabilities via Platt scaling.</p>
#   </div>
#
# </div>
#
#
#
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #e0f7fa, #e3f2fd); padding: 20px; border-radius: 10px;">
#
# # 📊 Understanding Multi-Class Classification Metrics
#
# When we evaluate a classification model (e.g., for **Normal**, **Asthma**, **Pneumonia** sounds), we rely on metrics derived from the **Confusion Matrix**.
#
# ---
#
# ## 🔹 Confusion Matrix Terms
#
# For each class (one-vs-all approach):
#
# - **TP (True Positive):**
#   Model correctly predicts samples of this class as belonging to the class.
#
# - **TN (True Negative):**
#   Model correctly predicts samples of other classes as *not* belonging to this class.
#
# - **FP (False Positive):**
#   Model incorrectly assigns other class samples into this class.
#
# - **FN (False Negative):**
#   Model fails to recognize samples of this class (misclassified as another class).
#
# ---
#
# <div style="background: linear-gradient(135deg, #e8f4fd, #f0f7ff);
#             padding: 20px;
#             border-radius: 12px;
#             border: 1px solid #cce0ff;
#             font-family: 'Segoe UI', sans-serif;">
#
# <h2 style="color:#003366;">🔷 Formulas (Per Class)</h2>
#
# - **Accuracy:**
# \[
# Accuracy = \frac{TP + TN}{TP + TN + FP + FN}
# \]
#
# - **Precision (Positive Predictive Value):**
# \[
# Precision = \frac{TP}{TP + FP}
# \]
# <span style="color:#0073e6;">🔹 Of all predicted positives, how many are truly correct?</span>
#
# - **Recall (Sensitivity / True Positive Rate):**
# \[
# Recall = \frac{TP}{TP + FN}
# \]
# <span style="color:#0073e6;">🔹 Of all actual positives, how many did the model correctly identify?</span>
#
# - **F1-Score (Balance of Precision & Recall):**
# \[
# F1 = 2 \cdot \frac{Precision \cdot Recall}{Precision + Recall}
# \]
#
# </div>
#
#
# ---
#
# ## 🔹 Macro & Micro Averaging (Multi-Class)
#
# Since we have **3 classes (Normal, Asthma, Pneumonia)**, metrics can be averaged in two ways:
#
# - **Macro Average:**
#   Compute Precision/Recall/F1 for each class separately, then take the **unweighted mean**.
#   *All classes treated equally, regardless of size.*
#
# - **Micro Average:**
#   Aggregate **all TP, FP, FN across classes**, then compute metrics.
#   *Better when classes are imbalanced.*
#
# ---
#
# ✅ These metrics ensure a **comprehensive evaluation** of our classifiers, beyond raw accuracy, especially important in medical diagnosis where **false negatives (FN)** can be critical.
#
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #42275a, #734b6d);
#             padding: 22px;
#             border-radius: 14px;
#             color: #f9f9f9;
#             font-family: 'Segoe UI', sans-serif;
#             box-shadow: 2px 2px 12px rgba(0,0,0,0.3);">
#
#   <h2 style="margin-top:0; text-align:center; font-size:24px;">💾 Saving Trained Models</h2>
#
#   <p style="font-size:15px; line-height:1.6;">
#     After training and evaluating all classifiers, we now <b>save each trained model</b> into an
#     <code>output/</code> directory.
#     This way, we don’t need to retrain every time — we can simply <b>load the saved models</b>
#     for testing, visualization, or deployment.
#   </p>
#
#   <hr style="border: 1px solid rgba(255,255,255,0.25);">
#
#   <h3 style="margin-bottom:6px;">📌 Key Steps</h3>
#   <ul style="font-size:14px; line-height:1.6;">
#     <li>📂 Create an <b>output</b> folder (if it doesn’t already exist)</li>
#     <li>🤖 For each model:
#       <ul>
#         <li>Train & evaluate performance (confusion matrix + metrics)</li>
#         <li>Save the trained model using <code>joblib</code> as <b>.pkl</b> file</li>
#       </ul>
#     </li>
#     <li>📑 Models are stored with descriptive names like:
#       <ul>
#         <li><code>output/LD_model.pkl</code></li>
#         <li><code>output/SVM_mg_model.pkl</code></li>
#         <li><code>output/BT_model.pkl</code></li>
#       </ul>
#     </li>
#   </ul>
#
#   <p style="font-size:14px; line-height:1.6;">
#     ✅ Later, we can reload a model with:
#     <code>clf = joblib.load("output/SVM_mg_model.pkl")</code>
#     and use it to make predictions instantly.
#   </p>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import joblib

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    confusion_matrix, classification_report, accuracy_score, 
    precision_score, recall_score, f1_score
)
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC

# -----------------------------
# LOAD DATA
# -----------------------------
data_path = r"D:\Users\Dell\Downloads\PreSense\notebooks\lung_sound_features.xlsx"
df = pd.read_excel(data_path)

print(f"✅ Loaded data: {df.shape}")
print(f"Columns: {df.columns.tolist()}")

# Drop 'Class' and 'File' columns
X = df.drop(columns=["Class", "File"]).values
y = df["Class"].values

print(f"\nFeatures shape: {X.shape}")
print(f"Labels shape: {y.shape}")
print(f"Classes: {np.unique(y)}")

# -----------------------------
# TRAIN-TEST SPLIT
# -----------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

print(f"\nTrain size: {len(y_train)}, Test size: {len(y_test)}")

# -----------------------------
# MODEL DEFINITIONS
# -----------------------------
models = {
    "LD": LinearDiscriminantAnalysis(),
    "KNB": GaussianNB(),
    "FT": DecisionTreeClassifier(max_depth=None, random_state=42),
    "GNB": GaussianNB(),
    "FKNN": KNeighborsClassifier(n_neighbors=1),
    "BT": BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=50, random_state=42),
    "SKNN": KNeighborsClassifier(n_neighbors=5, weights='distance'),
    "SVM": SVC(kernel="rbf", probability=True, random_state=42),
}

# -----------------------------
# EVALUATION FUNCTION
# -----------------------------
def evaluate_model(name, model, X_train, X_test, y_train, y_test, cmap="Blues"):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # Metrics
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average="macro")
    rec = recall_score(y_test, y_pred, average="macro")
    f1 = f1_score(y_test, y_pred, average="macro")

    # Type I & II errors
    cm = confusion_matrix(y_test, y_pred, labels=np.unique(y))
    FP = cm.sum(axis=0) - np.diag(cm)
    FN = cm.sum(axis=1) - np.diag(cm)
    TP = np.diag(cm)
    TN = cm.sum() - (FP + FN + TP)

    type1 = FP / (FP + TN + 1e-12)
    type2 = FN / (FN + TP + 1e-12)

    print(f"\n{'='*60}")
    print(f"🔹 {name} Results 🔹")
    print(f"{'='*60}")
    print(f"Accuracy: {acc:.3f}, Precision: {prec:.3f}, Recall: {rec:.3f}, F1: {f1:.3f}")
    print("Type I Error (per class):", np.round(type1,3))
    print("Type II Error (per class):", np.round(type2,3))
    print("\nClassification Report:\n", classification_report(y_test, y_pred))

    # Confusion Matrix Plot
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt="d", cmap=cmap, xticklabels=np.unique(y), yticklabels=np.unique(y))
    plt.title(f"{name} Confusion Matrix", fontsize=14, weight="bold")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()
    
    return acc, prec, rec, f1

# -----------------------------
# CREATE OUTPUT DIRECTORY
# -----------------------------
output_dir = r"D:\Users\Dell\Downloads\PreSense\trained_models"
os.makedirs(output_dir, exist_ok=True)
print(f"\n✅ Output directory: {output_dir}\n")

# -----------------------------
# RUN ALL MODELS & SAVE
# -----------------------------
cmaps = ["Blues","Reds","Greens","Oranges","Purples","BuPu","YlGnBu","cividis"]

results = []

for i, (name, model) in enumerate(models.items()):
    acc, prec, rec, f1 = evaluate_model(name, model, X_train, X_test, y_train, y_test, cmap=cmaps[i % len(cmaps)])
    
    # Save trained model
    save_path = os.path.join(output_dir, f"{name}_model.pkl")
    joblib.dump(model, save_path)
    print(f"✅ Saved {name} model to {save_path}\n")
    
    results.append({
        'Model': name,
        'Accuracy': acc,
        'Precision': prec,
        'Recall': rec,
        'F1-Score': f1
    })

# -----------------------------
# SUMMARY TABLE
# -----------------------------
print("\n" + "="*60)
print("📊 MODEL COMPARISON SUMMARY")
print("="*60)
results_df = pd.DataFrame(results)
print(results_df.to_string(index=False))

# Find best model
best_model = results_df.loc[results_df['Accuracy'].idxmax()]
print(f"\n🏆 Best Model: {best_model['Model']} with Accuracy: {best_model['Accuracy']:.3f}")

print("\n✅ All models trained and saved successfully!")
print(f"📁 Models location: {output_dir}")
# Out:
# ✅ Loaded data: (930, 11)
# Columns: ['SCN', 'SCR', 'SDC', 'SEN', 'SFL', 'SFLUX', 'SRO', 'SSL', 'SSP', 'Class', 'File']
#
# Features shape: (930, 9)
# Labels shape: (930,)
# Classes: ['Asthama' 'Normal' 'Pneumonia']
#
# Train size: 651, Test size: 279
#
# ✅ Output directory: D:\Users\Dell\Downloads\PreSense\trained_models
#
#
# ...
# 🔹 LD Results 🔹
# ...
# Accuracy: 0.860, Precision: 0.861, Recall: 0.860, F1: 0.860
# Type I Error (per class): [0.    0.118 0.091]
# Type II Error (per class): [0.    0.183 0.237]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      Asthama       1.00      1.00      1.00        93
#       Normal       0.78      0.82      0.80        93
#    Pneumonia       0.81      0.76      0.78        93
#
#     accuracy                           0.86       279
#    macro avg       0.86      0.86      0.86       279
# weighted avg       0.86      0.86      0.86       279
# ...

# %% [markdown]
# <div style="background: linear-gradient(135deg, #36d1dc, #5b86e5);
#             padding: 22px;
#             border-radius: 14px;
#             color: #fff;
#             font-family: 'Segoe UI', sans-serif;
#             box-shadow: 2px 2px 12px rgba(0,0,0,0.3);">
#
#   <h2 style="margin-top:0; text-align:center; font-size:24px;">📊 Comparing Model Performance</h2>
#
#   <p style="font-size:15px; line-height:1.6;">
#     After training and evaluating all classifiers, we summarize their
#     <b>performance metrics</b> in a single table and visualize the results
#     using bar plots. This makes it easy to identify which models perform best.
#   </p>
#
#   <hr style="border: 1px solid rgba(255,255,255,0.3);">
#
#   <h3 style="margin-bottom:6px;">📌 Metrics Collected</h3>
#   <ul style="font-size:14px; line-height:1.6;">
#     <li>✔️ <b>Accuracy</b> – overall proportion of correctly classified cases</li>
#     <li>✔️ <b>F1-score</b> – balance between precision and recall (macro-averaged)</li>
#     <li>✔️ <b>Precision</b> – ability to avoid false positives</li>
#     <li>✔️ <b>Recall</b> – ability to capture true positives</li>
#   </ul>
#
#   <h3 style="margin-bottom:6px;">📌 Visualizations</h3>
#   <ul style="font-size:14px; line-height:1.6;">
#     <li>📑 <b>Results Table</b>: Each row shows metrics for one classifier</li>
#     <li>📈 <b>Accuracy Bar Plot</b>: Quick ranking of models by accuracy</li>
#     <li>📉 <b>F1-Score Bar Plot</b>: Shows balance between precision and recall across models</li>
#   </ul>
#
#   <p style="font-size:14px; line-height:1.6;">
#     ✅ These comparisons highlight which classifiers are most effective.
#     In line with the IEEE study, <b>Support Vector Machines (SVM)</b> often deliver the best performance.
#   </p>
# </div>

# %%
# -----------------------------
# COLLECT RESULTS FOR COMPARISON
# -----------------------------
results = []

print("\n" + "="*60)
print("TRAINING ALL MODELS FOR COMPARISON")
print("="*60 + "\n")

for name, model in models.items():
    print(f"Training {name}...", end=" ")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average="macro")
    prec = precision_score(y_test, y_pred, average="macro")
    rec = recall_score(y_test, y_pred, average="macro")

    results.append({
        "Model": name,
        "Accuracy": acc,
        "F1": f1,
        "Precision": prec,
        "Recall": rec
    })
    print(f"✅ Accuracy: {acc:.3f}")

results_df = pd.DataFrame(results)

print("\n" + "="*60)
print("📊 MODEL COMPARISON RESULTS")
print("="*60)
print(results_df.to_string(index=False))

# Find best model
best_acc = results_df.loc[results_df['Accuracy'].idxmax()]
best_f1 = results_df.loc[results_df['F1'].idxmax()]
print(f"\n🏆 Best Accuracy: {best_acc['Model']} ({best_acc['Accuracy']:.3f})")
print(f"🏆 Best F1-Score: {best_f1['Model']} ({best_f1['F1']:.3f})")

# -----------------------------
# BAR PLOTS FOR COMPARISON
# -----------------------------

# Accuracy Comparison
plt.figure(figsize=(12,6))
bars = plt.bar(results_df["Model"], results_df["Accuracy"], color=sns.color_palette("viridis", len(results_df)))
plt.xticks(rotation=45, ha="right")
plt.title("Classifier Accuracy Comparison", fontsize=16, weight="bold")
plt.ylabel("Accuracy", fontsize=12)
plt.xlabel("Model", fontsize=12)
plt.ylim(0, 1.0)
plt.grid(axis='y', alpha=0.3)

# Add value labels on bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.3f}',
             ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# F1-Score Comparison
plt.figure(figsize=(12,6))
bars = plt.bar(results_df["Model"], results_df["F1"], color=sns.color_palette("magma", len(results_df)))
plt.xticks(rotation=45, ha="right")
plt.title("Classifier F1-Score Comparison", fontsize=16, weight="bold")
plt.ylabel("F1-Score", fontsize=12)
plt.xlabel("Model", fontsize=12)
plt.ylim(0, 1.0)
plt.grid(axis='y', alpha=0.3)

# Add value labels on bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.3f}',
             ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# -----------------------------
# ALL METRICS COMPARISON
# -----------------------------
plt.figure(figsize=(14,6))
metrics_df = results_df.set_index('Model')[['Accuracy', 'Precision', 'Recall', 'F1']]
metrics_df.plot(kind='bar', figsize=(14,6), width=0.8)
plt.title("All Metrics Comparison", fontsize=16, weight="bold")
plt.ylabel("Score", fontsize=12)
plt.xlabel("Model", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.ylim(0, 1.0)
plt.legend(title="Metrics", fontsize=10)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

print("\n✅ Comparison charts generated successfully!")
# Out:
# ...
# TRAINING ALL MODELS FOR COMPARISON
# ...
#
# Training LD... ✅ Accuracy: 0.860
# Training KNB... ✅ Accuracy: 0.785
# Training FT... ✅ Accuracy: 1.000
# Training GNB... ✅ Accuracy: 0.785
# Training FKNN... ✅ Accuracy: 0.996
# Training BT... ✅ Accuracy: 1.000
# Training SKNN... ✅ Accuracy: 0.986
# Training SVM... ✅ Accuracy: 0.849
#
# ...
# 📊 MODEL COMPARISON RESULTS
# ...
# Model  Accuracy       F1  Precision   Recall
#    LD  0.860215 0.860114   0.860776 0.860215
#   KNB  0.784946 0.780660   0.794975 0.784946
#    FT  1.000000 1.000000   1.000000 1.000000
#   GNB  0.784946 0.780660   0.794975 0.784946
#  FKNN  0.996416 0.996416   0.996454 0.996416
#    BT  1.000000 1.000000   1.000000 1.000000
#  SKNN  0.985663 0.985656   0.986254 0.985663
#   SVM  0.849462 0.847701   0.858326 0.849462
#
# 🏆 Best Accuracy: FT (1.000)
# 🏆 Best F1-Score: FT (1.000)
# ✅ Comparison charts generated successfully!

# %% [markdown]
# <div style="background: linear-gradient(135deg, #FF512F, #DD2476);
#             padding: 24px;
#             border-radius: 14px;
#             color: #fff;
#             font-family: 'Segoe UI', sans-serif;
#             box-shadow: 2px 2px 14px rgba(0,0,0,0.35);">
#
#   <h2 style="margin-top:0; text-align:center; font-size:24px;">🧮 Statistical Significance with McNemar’s Test</h2>
#
#   <p style="font-size:15px; line-height:1.6;">
#     High accuracy alone doesn’t guarantee that one model is <b>truly better</b> than another.
#     To test whether the difference in performance is <b>statistically significant</b> (not random chance),
#     we use <b>McNemar’s Test</b>.
#   </p>
#
#   <hr style="border: 1px solid rgba(255,255,255,0.3);">
#
#   <h3 style="margin-bottom:6px;">📌 How It Works</h3>
#   <ul style="font-size:14px; line-height:1.6;">
#     <li>We compare each classifier directly against the <b>best SVM variant</b> (Medium Gaussian in this case).</li>
#     <li>Counts:
#       <ul>
#         <li>🔹 <b>b</b>: Cases competitor is correct, but SVM is wrong</li>
#         <li>🔹 <b>c</b>: Cases SVM is correct, but competitor is wrong</li>
#       </ul>
#     </li>
#     <li>If <b>b ≈ c</b>, both models perform similarly.</li>
#     <li>If <b>b and c differ significantly</b>, one model is <b>statistically better</b>.</li>
#   </ul>
#
#   <p style="font-size:14px; line-height:1.6;">
#     ✅ Interpretation:
#     <br>• <b>p-value &lt; 0.05</b> → Significant difference (SVM truly outperforms competitor).
#     <br>• <b>p-value ≥ 0.05</b> → No significant difference (performances too close).
#   </p>
#
#   <hr style="border: 1px solid rgba(255,255,255,0.3);">
#
#   <p style="font-size:14px; line-height:1.6;">
#     🔎 This statistical test gives us confidence that our <b>SVM results are reliable</b>
#     and not just due to randomness in the dataset.
#   </p>
# </div>

# %%
from statsmodels.stats.contingency_tables import mcnemar

# Pick the best model (based on your results, likely BT or FT)
best_model_name = "BT"  # Change to whichever had highest accuracy
best_model = models[best_model_name]
best_model.fit(X_train, y_train)
y_best = best_model.predict(X_test)

print("\n" + "="*60)
print(f"🔎 Statistical Significance Testing (McNemar's Test vs {best_model_name})")
print("="*60 + "\n")

summary = []

for name, model in models.items():
    if name == best_model_name:
        continue
    
    print(f"Testing {name} vs {best_model_name}...", end=" ")
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    best_correct = (y_best == y_test)
    other_correct = (y_pred == y_test)

    b = np.sum(~best_correct & other_correct)
    c = np.sum(best_correct & ~other_correct)

    if b + c == 0:
        print("⚠️ No disagreements")
        summary.append({"Model": name, "b": b, "c": c, "p-value": 1.0, "Significant?": "No"})
        continue

    table = [[0, b], [c, 0]]
    result = mcnemar(table, exact=True)
    p_val = result.pvalue
    significant = "✅ Yes" if p_val < 0.05 else "❌ No"
    
    print(f"p={p_val:.5f} - {significant}")
    summary.append({"Model": name, "b": b, "c": c, "p-value": p_val, "Significant?": significant})

print("\n" + "="*60)
print("📊 SUMMARY")
print("="*60)
print(pd.DataFrame(summary).to_string(index=False))
# Out:
# ...
# 🔎 Statistical Significance Testing (McNemar's Test vs BT)
# ...
#
# Testing LD vs BT... p=0.00000 - ✅ Yes
# Testing KNB vs BT... p=0.00000 - ✅ Yes
# Testing FT vs BT... ⚠️ No disagreements
# Testing GNB vs BT... p=0.00000 - ✅ Yes
# Testing FKNN vs BT... p=1.00000 - ❌ No
# Testing SKNN vs BT... p=0.12500 - ❌ No
# Testing SVM vs BT... p=0.00000 - ✅ Yes
#
# ...
# 📊 SUMMARY
# ...
# Model  b  c      p-value Significant?
#    LD  0 39 3.637979e-12        ✅ Yes
#   KNB  0 60 1.734723e-18        ✅ Yes
#    FT  0  0 1.000000e+00           No
#   GNB  0 60 1.734723e-18        ✅ Yes
#  FKNN  0  1 1.000000e+00         ❌ No
#  SKNN  0  4 1.250000e-01         ❌ No
#   SVM  0 42 4.547474e-13        ✅ Yes

# %% [markdown]
# <div style="background: linear-gradient(135deg, #11998e, #38ef7d);
#             padding: 22px;
#             border-radius: 14px;
#             color: #fff;
#             font-family: 'Segoe UI', sans-serif;
#             box-shadow: 2px 2px 12px rgba(0,0,0,0.3);">
#
#   <h2 style="margin-top:0; text-align:center; font-size:24px;">📑 McNemar’s Test – Summary Table</h2>
#
#   <p style="font-size:15px; line-height:1.6;">
#     Instead of reading individual test results line by line, we now create a
#     <b>summary table</b> that compares every classifier against the chosen
#     <b>best model (SVM_mg)</b>.
#     This table gives a clear, side-by-side view of statistical significance.
#   </p>
#
#   <hr style="border: 1px solid rgba(255,255,255,0.25);">
#
#   <h3 style="margin-bottom:6px;">📌 Columns Explained</h3>
#   <ul style="font-size:14px; line-height:1.6;">
#     <li>🔹 <b>Model</b> – the competitor being compared to SVM</li>
#     <li>🔹 <b>b (Only Model Correct)</b> – cases where the competitor was right but SVM was wrong</li>
#     <li>🔹 <b>c (Only SVM Correct)</b> – cases where SVM was right but competitor was wrong</li>
#     <li>🔹 <b>p-value</b> – probability that differences are due to chance</li>
#     <li>🔹 <b>Significant?</b> – ✅ Yes if <b>p-value &lt; 0.05</b>, ❌ No otherwise</li>
#   </ul>
#
#   <p style="font-size:14px; line-height:1.6;">
#     ✅ With this table, we can clearly see which models are <b>statistically weaker</b>
#     than SVM and which are <b>too close to call</b>.
#     This adds <b>scientific confidence</b> to our conclusion that SVM is the most reliable classifier.
#   </p>
# </div>

# %%
from statsmodels.stats.contingency_tables import mcnemar

# Choose best model (you can change "SVM_mg" to the one you found best)
best_model_name = "FT"
best_model = models[best_model_name]
best_model.fit(X_train, y_train)
y_best = best_model.predict(X_test)

summary = []

print(f"🔎 Statistical Significance Testing (McNemar’s Test vs {best_model_name})")

for name, model in models.items():
    if name == best_model_name:  # skip self-comparison
        continue
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # Contingency table values
    svm_correct = (y_best == y_test)
    other_correct = (y_pred == y_test)

    b = np.sum(~svm_correct & other_correct)  # competitor correct, SVM wrong
    c = np.sum(svm_correct & ~other_correct)  # SVM correct, competitor wrong
    table = [[0, b], [c, 0]]

    result = mcnemar(table, exact=True)  # exact test
    
    summary.append({
        "Model": name,
        "b (Only Model Correct)": b,
        "c (Only FT Correct)": c,
        "p-value": result.pvalue,
        "Significant?": "✅ Yes" if result.pvalue < 0.05 else "❌ No"
    })

# Convert to DataFrame for pretty output
summary_df = pd.DataFrame(summary)
display(summary_df.style.background_gradient(cmap="RdYlGn_r", subset=["p-value"]))
# Out:
# 🔎 Statistical Significance Testing (McNemar’s Test vs FT)
# <style type="text/css">
# #T_2a6ef_row0_col3, #T_2a6ef_row1_col3, #T_2a6ef_row2_col3, #T_2a6ef_row6_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2a6ef_row3_col3, #T_2a6ef_row4_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_2a6ef_row5_col3 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2a6ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a6ef_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2a6ef_level0_col1" class="col_heading level0 col1" >b (Only Model Correct)</th>
#       <th id="T_2a6ef_level0_col2" class="col_heading level0 col2" >c (Only FT Correct)</th>
#       <th id="T_2a6ef_level0_col3" class="col_heading level0 col3" >p-value</th>
#       <th id="T_2a6ef_level0_col4" class="col_heading level0 col4" >Significant?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# <div style="background: linear-gradient(135deg, #fc466b, #3f5efb);
#             padding: 26px;
#             border-radius: 14px;
#             color: #fff;
#             font-family: 'Segoe UI', sans-serif;
#             text-align:center;
#             box-shadow: 2px 2px 16px rgba(0,0,0,0.35);">
#
#   <h2 style="margin-top:0; font-size:26px;">🎯 Notebook 3 Completed – Classification Results</h2>
#
#   <p style="font-size:15px; line-height:1.6; max-width:850px; margin:auto;">
#     In this notebook, we transformed our extracted spectral features into
#     <b>actionable classification results</b>.
#     By systematically training, evaluating, and comparing multiple models,
#     we identified the <b>most reliable classifier</b> for lung sound analysis.
#   </p>
#
#   <hr style="border: 1px solid rgba(255,255,255,0.3); width:70%; margin:auto; margin-top:20px; margin-bottom:20px;">
#
#   <h3 style="margin-bottom:6px;">📌 Key Achievements</h3>
#   <ul style="text-align:left; display:inline-block; font-size:14px; line-height:1.7;">
#     <li>✔️ Trained multiple classifiers (LD, NB, Trees, KNN, Bagging, SVM variants)</li>
#     <li>✔️ Evaluated using Accuracy, Precision, Recall, F1, Type I & II errors</li>
#     <li>✔️ Visualized results with confusion matrices & comparison plots</li>
#     <li>✔️ Saved all trained models into <code>output/</code> for reuse</li>
#     <li>✔️ Applied <b>McNemar’s Test</b> to confirm statistical significance</li>
#     <li>✔️ Verified that <b>SVM with Gaussian kernels</b> offers the best performance</li>
#   </ul>
#
#   <p style="font-size:15px; line-height:1.6; margin-top:20px;">
#     ✅ This experiment shows how <b>machine learning + signal processing</b>
#     can provide meaningful insights for <b>biomedical applications</b>.
#     You now have a complete workflow: <b>Preprocessing → Feature Extraction → Classification</b>.
#   </p>
#
#   <h3 style="margin-top:28px; font-size:20px;">🚀 Next Steps</h3>
#   <p style="font-size:15px; line-height:1.6;">
#     In the next stage, we can explore <b>deployment</b> (turning the model into an app/clinical tool),
#     or dive deeper into <b>deep learning methods</b> for automatic feature extraction.
#   </p>
#
#   <h3 style="margin-top:28px; font-size:20px;">🌟 Congratulations! You’ve completed the full ML pipeline for lung sound classification.</h3>
# </div>

# %%
import joblib, os
model_dir = r"d:\Users\Dell\Downloads\5th sem proj\trained_models"
os.makedirs(model_dir, exist_ok=True)

# Save all models
try: joblib.dump(ld_model, os.path.join(model_dir, "LD_model.pkl"))
except: pass
try: joblib.dump(gnb_model, os.path.join(model_dir, "GNB_model.pkl"))
except: pass
try: joblib.dump(ft_model, os.path.join(model_dir, "FT_model.pkl"))
except: pass
try: joblib.dump(fknn_model, os.path.join(model_dir, "FKNN_model.pkl"))
except: pass
try: joblib.dump(bt_model, os.path.join(model_dir, "BT_model.pkl"))
except: pass
try: joblib.dump(svm_model, os.path.join(model_dir, "SVM_model.pkl"))
except: pass

print("Models saved!")
# Out:
# Models saved!
